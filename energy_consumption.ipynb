# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:/Users/mushraf/.cache/kagglehub/datasets/fedesoriano/electric-power-consumption/versions/1/powerconsumption.csv')

# %%
df
# Out:
#                Datetime  Temperature  Humidity  WindSpeed  \
# 0         1/1/2017 0:00        6.559      73.8      0.083
# 1         1/1/2017 0:10        6.414      74.5      0.083
# 2         1/1/2017 0:20        6.313      74.5      0.080
# 3         1/1/2017 0:30        6.121      75.0      0.083
# 4         1/1/2017 0:40        5.921      75.7      0.081
# ...                 ...          ...       ...        ...
# 52411  12/30/2017 23:10        7.010      72.4      0.080
# 52412  12/30/2017 23:20        6.947      72.6      0.082
# 52413  12/30/2017 23:30        6.900      72.8      0.086
# 52414  12/30/2017 23:40        6.758      73.0      0.080
# 52415  12/30/2017 23:50        6.580      74.1      0.081
#
#        GeneralDiffuseFlows  DiffuseFlows  PowerConsumption_Zone1  \
# 0                    0.051         0.119             34055.69620
# 1                    0.070         0.085             29814.68354
# 2                    0.062         0.100             29128.10127
# ...

# %%
#Data Exploration

# %%
df.head()
# Out:
#         Datetime  Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# 0  1/1/2017 0:00        6.559      73.8      0.083                0.051
# 1  1/1/2017 0:10        6.414      74.5      0.083                0.070
# 2  1/1/2017 0:20        6.313      74.5      0.080                0.062
# 3  1/1/2017 0:30        6.121      75.0      0.083                0.091
# 4  1/1/2017 0:40        5.921      75.7      0.081                0.048
#
#    DiffuseFlows  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0         0.119             34055.69620             16128.87538
# 1         0.085             29814.68354             19375.07599
# 2         0.100             29128.10127             19006.68693
# 3         0.096             28228.86076             18361.09422
# 4         0.085             27335.69620             17872.34043
#
#    PowerConsumption_Zone3
# 0             20240.96386
# 1             20131.08434
# 2             19668.43373
# 3             18899.27711
# ...

# %%
df.tail(3)
# Out:
#                Datetime  Temperature  Humidity  WindSpeed  \
# 52413  12/30/2017 23:30        6.900      72.8      0.086
# 52414  12/30/2017 23:40        6.758      73.0      0.080
# 52415  12/30/2017 23:50        6.580      74.1      0.081
#
#        GeneralDiffuseFlows  DiffuseFlows  PowerConsumption_Zone1  \
# 52413                0.084         0.074             29590.87452
# 52414                0.066         0.089             28958.17490
# 52415                0.062         0.111             28349.80989
#
#        PowerConsumption_Zone2  PowerConsumption_Zone3
# 52413             25277.69254             13806.48259
# 52414             24692.23688             13512.60504
# 52415             24055.23167             13345.49820

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52416 entries, 0 to 52415
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Datetime                52416 non-null  object
#  1   Temperature             52416 non-null  float64
#  2   Humidity                52416 non-null  float64
#  3   WindSpeed               52416 non-null  float64
#  4   GeneralDiffuseFlows     52416 non-null  float64
#  5   DiffuseFlows            52416 non-null  float64
#  6   PowerConsumption_Zone1  52416 non-null  float64
#  7   PowerConsumption_Zone2  52416 non-null  float64
#  8   PowerConsumption_Zone3  52416 non-null  float64
# dtypes: float64(8), object(1)
# memory usage: 3.6+ MB

# %%
df.describe()
# Out:
#         Temperature      Humidity     WindSpeed  GeneralDiffuseFlows  \
# count  52416.000000  52416.000000  52416.000000         52416.000000
# mean      18.810024     68.259518      1.959489           182.696614
# std        5.815476     15.551177      2.348862           264.400960
# min        3.247000     11.340000      0.050000             0.004000
# 25%       14.410000     58.310000      0.078000             0.062000
# 50%       18.780000     69.860000      0.086000             5.035500
# 75%       22.890000     81.400000      4.915000           319.600000
# max       40.010000     94.800000      6.483000          1163.000000
#
#        DiffuseFlows  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# count  52416.000000            52416.000000            52416.000000
# mean      75.028022            32344.970564            21042.509082
# std      124.210949             7130.562564             5201.465892
# min        0.011000            13895.696200             8560.081466
# ...

# %%
print(df.describe(),"\n")
# Out:
#         Temperature      Humidity     WindSpeed  GeneralDiffuseFlows  \
# count  52416.000000  52416.000000  52416.000000         52416.000000
# mean      18.810024     68.259518      1.959489           182.696614
# std        5.815476     15.551177      2.348862           264.400960
# min        3.247000     11.340000      0.050000             0.004000
# 25%       14.410000     58.310000      0.078000             0.062000
# 50%       18.780000     69.860000      0.086000             5.035500
# 75%       22.890000     81.400000      4.915000           319.600000
# max       40.010000     94.800000      6.483000          1163.000000
#
#        DiffuseFlows  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# count  52416.000000            52416.000000            52416.000000
# mean      75.028022            32344.970564            21042.509082
# std      124.210949             7130.562564             5201.465892
# min        0.011000            13895.696200             8560.081466
# ...

# %%
df.head(3)
# Out:
#         Datetime  Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# 0  1/1/2017 0:00        6.559      73.8      0.083                0.051
# 1  1/1/2017 0:10        6.414      74.5      0.083                0.070
# 2  1/1/2017 0:20        6.313      74.5      0.080                0.062
#
#    DiffuseFlows  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0         0.119             34055.69620             16128.87538
# 1         0.085             29814.68354             19375.07599
# 2         0.100             29128.10127             19006.68693
#
#    PowerConsumption_Zone3
# 0             20240.96386
# 1             20131.08434
# 2             19668.43373

# %%
df
# Out:
#                Datetime  Temperature  Humidity  WindSpeed  \
# 0         1/1/2017 0:00        6.559      73.8      0.083
# 1         1/1/2017 0:10        6.414      74.5      0.083
# 2         1/1/2017 0:20        6.313      74.5      0.080
# 3         1/1/2017 0:30        6.121      75.0      0.083
# 4         1/1/2017 0:40        5.921      75.7      0.081
# ...                 ...          ...       ...        ...
# 52411  12/30/2017 23:10        7.010      72.4      0.080
# 52412  12/30/2017 23:20        6.947      72.6      0.082
# 52413  12/30/2017 23:30        6.900      72.8      0.086
# 52414  12/30/2017 23:40        6.758      73.0      0.080
# 52415  12/30/2017 23:50        6.580      74.1      0.081
#
#        GeneralDiffuseFlows  DiffuseFlows  PowerConsumption_Zone1  \
# 0                    0.051         0.119             34055.69620
# 1                    0.070         0.085             29814.68354
# 2                    0.062         0.100             29128.10127
# ...

# %%
# Feature Extraction

# %%
df = df.drop("WindSpeed", axis=1)

# %%
df = df.drop("Temperature", axis=1)

# %%
df = df.drop("Humidity", axis=1)
df = df.drop("GeneralDiffuseFlows", axis=1)

# %%
df = df.drop("DiffuseFlows", axis=1)

# %%
df
# Out:
#                Datetime  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0         1/1/2017 0:00             34055.69620             16128.87538
# 1         1/1/2017 0:10             29814.68354             19375.07599
# 2         1/1/2017 0:20             29128.10127             19006.68693
# 3         1/1/2017 0:30             28228.86076             18361.09422
# 4         1/1/2017 0:40             27335.69620             17872.34043
# ...                 ...                     ...                     ...
# 52411  12/30/2017 23:10             31160.45627             26857.31820
# 52412  12/30/2017 23:20             30430.41825             26124.57809
# 52413  12/30/2017 23:30             29590.87452             25277.69254
# 52414  12/30/2017 23:40             28958.17490             24692.23688
# 52415  12/30/2017 23:50             28349.80989             24055.23167
#
#        PowerConsumption_Zone3
# 0                 20240.96386
# 1                 20131.08434
# ...

# %%
dataset = df
dataset["Month"] = pd.to_datetime(df["Datetime"]).dt.month
dataset["Year"] = pd.to_datetime(df["Datetime"]).dt.year
dataset["Date"] = pd.to_datetime(df["Datetime"]).dt.date
dataset["Time"] = pd.to_datetime(df["Datetime"]).dt.time
dataset["Week"] = pd.to_datetime(df["Datetime"]).dt.week
dataset["Day"] = pd.to_datetime(df["Datetime"]).dt.day_name()
dataset = df.set_index("Datetime")
dataset.index = pd.to_datetime(dataset.index)
# Out:
# C:\Users\mushraf\anaconda3\envs\rtutorial\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.

# %%
dataset
# Out:
#                      PowerConsumption_Zone1  PowerConsumption_Zone2  \
# Datetime
# 2017-01-01 00:00:00             34055.69620             16128.87538
# 2017-01-01 00:10:00             29814.68354             19375.07599
# 2017-01-01 00:20:00             29128.10127             19006.68693
# 2017-01-01 00:30:00             28228.86076             18361.09422
# 2017-01-01 00:40:00             27335.69620             17872.34043
# ...                                     ...                     ...
# 2017-12-30 23:10:00             31160.45627             26857.31820
# 2017-12-30 23:20:00             30430.41825             26124.57809
# 2017-12-30 23:30:00             29590.87452             25277.69254
# 2017-12-30 23:40:00             28958.17490             24692.23688
# 2017-12-30 23:50:00             28349.80989             24055.23167
#
#                      PowerConsumption_Zone3  Month  Year        Date  \
# Datetime
# ...

# %%
dataset.head()
# Out:
#                      PowerConsumption_Zone1  PowerConsumption_Zone2  \
# Datetime
# 2017-01-01 00:00:00             34055.69620             16128.87538
# 2017-01-01 00:10:00             29814.68354             19375.07599
# 2017-01-01 00:20:00             29128.10127             19006.68693
# 2017-01-01 00:30:00             28228.86076             18361.09422
# 2017-01-01 00:40:00             27335.69620             17872.34043
#
#                      PowerConsumption_Zone3  Month  Year        Date  \
# Datetime
# 2017-01-01 00:00:00             20240.96386      1  2017  2017-01-01
# 2017-01-01 00:10:00             20131.08434      1  2017  2017-01-01
# 2017-01-01 00:20:00             19668.43373      1  2017  2017-01-01
# 2017-01-01 00:30:00             18899.27711      1  2017  2017-01-01
# 2017-01-01 00:40:00             18442.40964      1  2017  2017-01-01
#
#                          Time  Week     Day
# Datetime
# 2017-01-01 00:00:00  00:00:00    52  Sunday
# ...

# %%
print("")
print("Total Number of Years: ", dataset.Year.nunique() )
print(dataset.Year.unique())
# Out:
# Total Number of Years:  1
# [2017]

# %%
df['totalpowerconsumption']=df['PowerConsumption_Zone1']+df['PowerConsumption_Zone2']+df['PowerConsumption_Zone3']

# %%
df['totalpowerconsumption']
# Out:
# 0        70425.53544
# 1        69320.84387
# 2        67803.22193
# 3        65489.23209
# 4        63650.44627
#             ...
# 52411    72798.08659
# 52412    70983.80786
# 52413    68675.04965
# 52414    67163.01682
# 52415    65750.53976
# Name: totalpowerconsumption, Length: 52416, dtype: float64

# %%
df
# Out:
#                Datetime  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0         1/1/2017 0:00             34055.69620             16128.87538
# 1         1/1/2017 0:10             29814.68354             19375.07599
# 2         1/1/2017 0:20             29128.10127             19006.68693
# 3         1/1/2017 0:30             28228.86076             18361.09422
# 4         1/1/2017 0:40             27335.69620             17872.34043
# ...                 ...                     ...                     ...
# 52411  12/30/2017 23:10             31160.45627             26857.31820
# 52412  12/30/2017 23:20             30430.41825             26124.57809
# 52413  12/30/2017 23:30             29590.87452             25277.69254
# 52414  12/30/2017 23:40             28958.17490             24692.23688
# 52415  12/30/2017 23:50             28349.80989             24055.23167
#
#        PowerConsumption_Zone3  Month  Year        Date      Time  Week  \
# ...

# %%
dataset=df
dataset
# Out:
#                Datetime  PowerConsumption_Zone1  PowerConsumption_Zone2  \
# 0         1/1/2017 0:00             34055.69620             16128.87538
# 1         1/1/2017 0:10             29814.68354             19375.07599
# 2         1/1/2017 0:20             29128.10127             19006.68693
# 3         1/1/2017 0:30             28228.86076             18361.09422
# 4         1/1/2017 0:40             27335.69620             17872.34043
# ...                 ...                     ...                     ...
# 52411  12/30/2017 23:10             31160.45627             26857.31820
# 52412  12/30/2017 23:20             30430.41825             26124.57809
# 52413  12/30/2017 23:30             29590.87452             25277.69254
# 52414  12/30/2017 23:40             28958.17490             24692.23688
# 52415  12/30/2017 23:50             28349.80989             24055.23167
#
#        PowerConsumption_Zone3  Month  Year        Date      Time  Week  \
# ...

# %%
#Data Visualizations

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import style
fig = plt.figure()
axes1 = plt.subplot2grid((1,1), (0,0))

style.use("ggplot")
sns.lineplot(x= dataset["Month"], y= dataset["PowerConsumption_Zone1"], data = dataset) #x dataset taken as Month since unique year is 2017
sns.set(rc={'figure.figsize': (20,10)})

plt.title("Electricity consumption")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True)
plt.legend()

for label in axes1.xaxis.get_ticklabels():
    label.set_rotation(90)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from matplotlib import style
fig = plt.figure()
axes1 = plt.subplot2grid((1,1), (0,0))

style.use("ggplot")
sns.lineplot(x= dataset["Month"], y= dataset["PowerConsumption_Zone2"], data = dataset) #x dataset taken as Month since unique year is 2017
sns.set(rc={'figure.figsize': (20,10)})

plt.title("Electricity consumption")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True)
plt.legend()

for label in axes1.xaxis.get_ticklabels():
    label.set_rotation(90)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from matplotlib import style
fig = plt.figure()
axes1 = plt.subplot2grid((1,1), (0,0))

style.use("ggplot")
sns.lineplot(x= dataset["Month"], y= dataset["PowerConsumption_Zone3"], data = dataset) #x dataset taken as Month since unique year is 2017
sns.set(rc={'figure.figsize': (20,10)})

plt.title("Electricity consumption")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True)
plt.legend()

for label in axes1.xaxis.get_ticklabels():
    label.set_rotation(10)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from matplotlib import style
fig = plt.figure()
axes1 = plt.subplot2grid((1,1), (0,0))

style.use("ggplot")
sns.lineplot(x= dataset["Month"], y= dataset["totalpowerconsumption"], data = dataset) #x dataset taken as Month since unique year is 2017
sns.set(rc={'figure.figsize': (20,10)})

plt.title("Electricity consumption")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True)
plt.legend()

for label in axes1.xaxis.get_ticklabels():
    label.set_rotation(90)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
plt.figure(figsize=(15,10))
plt.plot(dataset["totalpowerconsumption"])

# %%
from matplotlib import style

fig = plt.figure(figsize = (30,30))

ax1 = fig.add_subplot(611)
ax2 = fig.add_subplot(612)
ax3 = fig.add_subplot(613)
ax4 = fig.add_subplot(614)

style.use("ggplot")
dataset["Date"]=pd.to_datetime(dataset['Date'])
data_2017=dataset[dataset["Date"].dt.year==2017]
y_2017 = data_2017["PowerConsumption_Zone1"].tolist()
x_2017 = data_2017["Date"].tolist()
ax1.plot(x_2017, y_2017, color= "blue", linewidth= 1.7)

#month_1 vs powerconsumption_zone1
dataset["Month"]=pd.to_datetime(dataset["Month"])
data_january=dataset[dataset["Month"].dt.month==1]
y_january = data_january["PowerConsumption_Zone1"].tolist()
x_january = data_january["Month"].tolist()
ax2.plot(x_january, y_january, color= "blue", linewidth= 1.7)

#month_1 vs totalpowerconsumption
dataset["Month"]=pd.to_datetime(dataset["Month"])
data_january=dataset[dataset["Month"].dt.month==1]
y_january = data_january["totalpowerconsumption"].tolist()
x_january = data_january["Month"].tolist()
ax3.plot(x_january, y_january, color= "blue", linewidth= 1.7)

#month_2 vs powerconsumption_zone1
dataset["Month"]=pd.to_datetime(dataset["Month"])
data_february=dataset[dataset["Month"].dt.month==2]
y_february = data_february["PowerConsumption_Zone1"].tolist()
x_february = data_february["Month"].tolist()
ax4.plot(x_february, y_february, color= "blue", linewidth= 1.7)

# %%
fig = plt.figure(figsize = (15,10))
sns.distplot(dataset["totalpowerconsumption"])
plt.title("Energy Distribution")
# Out:
# C:\Users\mushraf\anaconda3\envs\rtutorial\lib\site-packages\ipykernel_launcher.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
# Text(0.5, 1.0, 'Energy Distribution')

# %%
fig = plt.figure(figsize = (15,10))
sns.boxplot(x=dataset["Month"], y=dataset["totalpowerconsumption"], data= df)
plt.title("Energy Consumption VS Month")
plt.xlabel("Month")
plt.grid(True, alpha=1)
plt.legend(title="my legend", handles=[])

for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)

# %%
fig = plt.figure(figsize = (5,5))
sns.boxplot(x=dataset["Year"], y=dataset["PowerConsumption_Zone1"], data= df)
plt.title("Energy Consumption VS Month")
plt.xlabel("Month")
plt.grid(True, alpha=1)
plt.legend()

for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#LSTM Model
#Train, Validation and Test Dataset

# %%
print(df.columns)
# Out:
# Index(['Datetime', 'PowerConsumption_Zone1', 'PowerConsumption_Zone2',
#        'PowerConsumption_Zone3', 'Month', 'Year', 'Date', 'Time', 'Week',
#        'Day', 'totalpowerconsumption'],
#       dtype='object')

# %%
# Downsampling involves decreasing the time-frequency of the data
# Downsapling the time-frequency from hours to days 
df['Date']=pd.to_datetime(df['Datetime'])
df.set_index('Date',inplace=True)

# %%
newDataSet = dataset.resample("D").mean()

# %%
newDataSet
# Out:
#             PowerConsumption_Zone1  PowerConsumption_Zone2  \
# Date
# 2017-01-01            28465.232067            17737.791287
# 2017-01-02            28869.493671            19557.725431
# 2017-01-03            30562.447257            20057.269504
# 2017-01-04            30689.831224            20102.077001
# 2017-01-05            30802.911393            20033.941237
# ...                            ...                     ...
# 2017-12-26            30013.476975            24757.006239
# 2017-12-27            29966.962399            25057.481845
# 2017-12-28            30267.004647            24585.251099
# 2017-12-29            29209.632446            24610.821315
# 2017-12-30            28145.669624            24211.286693
#
#             PowerConsumption_Zone3    Year  Week  totalpowerconsumption
# Date
# 2017-01-01            17868.795181  2017.0  52.0           64071.818534
# 2017-01-02            17820.763053  2017.0   1.0           66247.982154
# ...

# %%
print("Old Dataset: ", dataset.shape)
print("New Dataset: ", newDataSet.shape)
# Out:
# Old Dataset:  (52416, 10)
# New Dataset:  (364, 6)

# %%
# Saving data in CSV new file
# newDataSet.to_csv("newDataSet.csv")
# from google.colab import files
# files.download("newDataSet.csv")

# %%
newDataSet.count()
# Out:
# PowerConsumption_Zone1    364
# PowerConsumption_Zone2    364
# PowerConsumption_Zone3    364
# Year                      364
# Week                      364
# totalpowerconsumption     364
# dtype: int64

# %%
newDataSet.head()
# Out:
#             PowerConsumption_Zone1  PowerConsumption_Zone2  \
# Date
# 2017-01-01            28465.232067            17737.791287
# 2017-01-02            28869.493671            19557.725431
# 2017-01-03            30562.447257            20057.269504
# 2017-01-04            30689.831224            20102.077001
# 2017-01-05            30802.911393            20033.941237
#
#             PowerConsumption_Zone3    Year  Week  totalpowerconsumption
# Date
# 2017-01-01            17868.795181  2017.0  52.0           64071.818534
# 2017-01-02            17820.763053  2017.0   1.0           66247.982154
# 2017-01-03            17620.803213  2017.0   1.0           68240.519974
# 2017-01-04            17673.694779  2017.0   1.0           68465.603003
# 2017-01-05            17664.176707  2017.0   1.0           68501.029337

# %%
y = newDataSet["totalpowerconsumption"]
print(y[0])
y.shape
# Out:
# 64071.81853444445
# (364,)

# %%
# Normalize data before model fitting
# it will boost the performance( in neural networks) + transform
from sklearn.preprocessing import MinMaxScaler
# scale of the output and input inthe range 0-1 to match the scale of the layer of LSTM
scaler = MinMaxScaler(feature_range = (0,1)) 
# reshape: convert the univariate 1D array into 2D
y = scaler.fit_transform(np.array(y).reshape(-1,1))
print("Normalizing data before model fitting")
print(y[:10])
# Out:
# Normalizing data before model fitting
# [[0.13926892]
#  [0.1943963 ]
#  [0.244872  ]
#  [0.25057388]
#  [0.25147132]
#  [0.24721696]
#  [0.23500646]
#  [0.1524373 ]
#  [0.21498382]
#  [0.25635721]]

# %%
# building input variable
def create_dataset(dataset, time_step = 1):
  dataX, dataY = [] , []
  for i in range(len(dataset)-time_step-1):
    a = dataset[i:(i+time_step),0]
    dataX.append(a)
    dataY.append(dataset[i + time_step,0])
  return np.array(dataX), np.array(dataY)

# %%
import numpy as np

# 1. Define your time window
time_step = 45

# 2. Create dataset function
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        dataX.append(dataset[i:(i+time_step), 0])  # Input window
        dataY.append(dataset[i+time_step, 0])       # Next value prediction
    return np.array(dataX), np.array(dataY)

# 3. Split your data (assuming 'y' is loaded)
total_samples = len(y)
train_size = int(total_samples * 0.64)  # 64%
val_size = int(total_samples * 0.16)    # 16%
test_size = total_samples - train_size - val_size  # 20%

train_data = y[:train_size]
val_data = y[train_size:train_size+val_size]
test_data = y[train_size+val_size:]

# 4. Create sequences
X_train, y_train = create_dataset(train_data, time_step)
X_val, y_val = create_dataset(val_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# 5. Reshape for LSTM [samples, timesteps, features]
X_train = X_train.reshape(-1, time_step, 1)
X_val = X_val.reshape(-1, time_step, 1)
X_test = X_test.reshape(-1, time_step, 1)

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler(feature_range=(0, 1))
y_train = scaler.fit_transform(y_train.reshape(-1, 1))
y_val = scaler.transform(y_val.reshape(-1, 1))
y_test = scaler.transform(y_test.reshape(-1, 1))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
import tensorflow as tf

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from keras.regularizers import l2

model = Sequential([
    LSTM(32, input_shape=(time_step, 1), 
         kernel_regularizer=l2(0.01),
         recurrent_regularizer=l2(0.01)),
    Dropout(0.3),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')

# %%
#modelfitting 
history = model.fit(X_train, y_train, validation_split=0.2, verbose = 1,epochs = 60 ,batch_size = 20)
# Out:
# Epoch 1/60
# 8/8 [==============================] - 5s 153ms/step - loss: 0.4017 - val_loss: 0.7078
# Epoch 2/60
# 8/8 [==============================] - 0s 21ms/step - loss: 0.3233 - val_loss: 0.4496
# Epoch 3/60
# 8/8 [==============================] - 0s 19ms/step - loss: 0.2711 - val_loss: 0.3196
# Epoch 4/60
# 8/8 [==============================] - 0s 21ms/step - loss: 0.2416 - val_loss: 0.2904
# Epoch 5/60
# 8/8 [==============================] - 0s 18ms/step - loss: 0.2105 - val_loss: 0.2850
# Epoch 6/60
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1878 - val_loss: 0.2804
# Epoch 7/60
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1637 - val_loss: 0.2652
# Epoch 8/60
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1480 - val_loss: 0.2299
# Epoch 9/60
# 8/8 [==============================] - 0s 18ms/step - loss: 0.1304 - val_loss: 0.2048
# Epoch 10/60
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm (LSTM)                 (None, 32)                4352
#
#  dropout (Dropout)           (None, 32)                0
#
#  dense (Dense)               (None, 1)                 33
#
# ...
# Total params: 4,385
# Trainable params: 4,385
# Non-trainable params: 0
# _________________________________________________________________

# %%
#Model Evaluating 

plt.figure(figsize=(10,10))
plt.plot(history.history['loss']) 
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'val_loss'])

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)
val_predict=model.predict(X_val)
# Out:
# ...
# 1/1 [==============================] - 0s 36ms/step

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
val_predict=scaler.inverse_transform(val_predict)

# %%
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
     
print(train_predict.shape)
print(test_predict.shape)
print(val_predict.shape)
print(train_predict[0])
print(y_train.shape)
# Out:
# (186, 1)
# (28, 1)
# (12, 1)
# [0.21766886]
# (186, 1)

# %%
# Predicting consumption using training data
train_predictions = model.predict(X_train)
train_predictions =scaler.inverse_transform(train_predictions)

y_train = y_train.reshape(y_train.shape[0], 1)
actual = scaler.inverse_transform(y_train)
train_results = pd.DataFrame()

train_results["Train Predictions"] = train_predictions.tolist()
train_results["Actuals"] = actual.tolist()

train_results
# Out:
# 6/6 [==============================] - 0s 7ms/step
#          Train Predictions                Actuals
# 0    [0.21766886115074158]  [0.24971442400651608]
# 1     [0.2245374172925949]   [0.2657850854117818]
# 2    [0.23308007419109344]  [0.23652119072494804]
# 3    [0.23493461310863495]  [0.20892822856625992]
# 4    [0.23154139518737793]   [0.1932453507064651]
# ..                     ...                    ...
# 181   [0.7734225392341614]   [0.7599756340219612]
# 182   [0.7715566158294678]   [0.7796651582495209]
# 183    [0.773393452167511]   [0.8025674280861435]
# 184   [0.7788657546043396]   [0.7774096562909982]
# 185    [0.779069185256958]   [0.7495441053364698]
#
# [186 rows x 2 columns]

# %%
print(y.shape) , print(actual.shape) , print(train_predictions.shape)
# Out:
# (364, 1)
# (186, 1)
# (186, 1)
# (None, None, None)

# %%
plt.figure(figsize=(20,10))

# Create array with correct size
plot_length = max(len(actual), len(y) - 186)  # Use the larger dimension
ActualPlot = np.empty((plot_length, 1))
ActualPlot[:, :] = np.nan
ActualPlot[-len(actual):, :] = actual  # Fill from the end

TrainPredictionsPlot = np.empty((plot_length, 1))
TrainPredictionsPlot[:, :] = np.nan
TrainPredictionsPlot[-len(train_predictions):, :] = train_predictions

plt.plot(ActualPlot)
plt.plot(TrainPredictionsPlot)
plt.legend(['actual','train_predictions'])
plt.xlabel('Time Steps')
plt.ylabel('Consumption MWh')
plt.show()

# %%
# Predicting consumption using validation data
val_predictions = model.predict(X_val)
val_predictions =scaler.inverse_transform(val_predictions)

y_val = y_val.reshape(y_val.shape[0], 1)
actual_val = scaler.inverse_transform(y_val)

val_results = pd.DataFrame()
val_results["Val Predictions"] = val_predictions.tolist()
val_results["Actuals_val"] = actual_val.tolist()

val_results
# Out:
# 1/1 [==============================] - 0s 42ms/step
#           Val Predictions            Actuals_val
# 0   [0.24558250606060028]  [0.27661305701124705]
# 1    [0.2522757947444916]  [0.25657089749438966]
# 2    [0.2542559802532196]  [0.25068258184992764]
# 3   [0.25484514236450195]  [0.17258776475283044]
# 4   [0.24142557382583618]   [0.2511545722023045]
# 5   [0.24429240822792053]  [0.24835309158423247]
# 6   [0.24617406725883484]  [0.26648800965195263]
# 7    [0.2509707510471344]    [0.290703754045214]
# 8    [0.2592577040195465]   [0.2645308342032786]
# 9    [0.2614586055278778]  [0.25756077615738304]
# 10  [0.26203271746635437]   [0.1574858872208058]
# 11  [0.24468183517456055]  [0.26884302245307246]

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)
val_predict=scaler.inverse_transform(val_predict)

# %%
#value predictions versus actual predictions
import numpy as np
import matplotlib.pyplot as plt

series_length = len(y)

# Get lengths of actual and predictions
actual_len = actual.shape[0]
pred_len = train_predictions.shape[0]

# Create NaN-filled arrays of the appropriate shape
ActualPlot = np.full((364, 1), np.nan)
TrainPredictionPlot = np.full((364, 1), np.nan)

# Set starting index
start_index = 162

# Ensure we don't go out of bounds
ActualPlot[start_index:start_index + actual_len, 0] = actual[:min(364 - start_index, actual_len), 0]
TrainPredictionPlot[start_index:start_index + pred_len, 0] = train_predictions[:min(364 - start_index, pred_len), 0]

# Plotting
plt.figure(figsize=(20, 10))
plt.plot(ActualPlot, label="Actual")
plt.plot(TrainPredictionPlot, label="Train Predictions")
plt.xlabel("TimeSteps")
plt.ylabel("Consumption MWh")
plt.legend()
plt.show()

# %%
#Type and Shape
print("Input shapes:")
print(f"X_train: {X_train.shape} (dtype: {X_train.dtype})")
print(f"X_val: {X_val.shape} (dtype: {X_val.dtype})")
print(f"X_test: {X_test.shape} (dtype: {X_test.dtype})")

print("\nOutput shapes:")
print(f"y_train: {y_train.shape}")
print(f"y_val: {y_val.shape}")
print(f"y_test: {y_test.shape}")
# Out:
# Input shapes:
# X_train: (186, 45, 1) (dtype: float64)
# X_val: (12, 45, 1) (dtype: float64)
# X_test: (28, 45, 1) (dtype: float64)
#
# Output shapes:
# y_train: (186, 1)
# y_val: (12, 1)
# y_test: (28, 1)
